# %%
import h5py
import pylab as plt
import os

# %%
data_dir = './'

# %% [markdown]
# ## BBH

# %%
samples_file = os.path.join(data_dir, 'pop2_m_FP4_spin_IB_fref_5.0_z_MD_lmr_130_BBH_34K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['a_1', 'a_2', 'chi_1_in_plane', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'cos_tilt_1', 'cos_tilt_2', 'dec', 'geocent_time', 'iota', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'phi_1', 'phi_12', 'phi_2', 'phi_jl', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'tilt_1', 'tilt_2', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'a_1': array([0.49842259, 0.67979439, 0.57798028, ..., 0.7502986 , 0.09798943,
#         0.95808458]),
#  'a_2': array([0.14241547, 0.33965816, 0.12221886, ..., 0.43991329, 0.9581741 ,
#         0.24050518]),
#  'chi_1_in_plane': array([0.46508705, 0.66383784, 0.53809535, ..., 0.63174448, 0.0446421 ,
#         0.32312007]),
#  'chi_2_in_plane': array([0.07989252, 0.25248684, 0.06229967, ..., 0.43884043, 0.4643448 ,
#         0.23989843]),
#  'chi_eff': array([ 0.15097008,  0.17852965, -0.15915568, ...,  0.22371987,
#         -0.3589485 ,  0.48092032]),
#  'chi_p': array([0.46508705, 0.66383784, 0.53809535, ..., 0.63174448, 0.42796787,
#         0.32312007]),
#  'chirp_mass': array([15.7329015 , 35.40725358, 18.2886898 , ..., 17.65651862,
#         18.76833105, 13.58604638]),
#  'chirp_mass_source': array([7.13840104, 8.62005547, 7.32029202, ..., 7.34127186, 7.63669727,
#         7.54332512]),
#  'cos_tilt_1': array([ 0.3595705 ,  0.21539331, -0.36503812, ...,  0.53949196,
# ...

# %% [markdown]
# ## NSBH

# %%
samples_file = os.path.join(data_dir, 'pop2_m_FP4_spin_GNS_fref_5.0_z_MD_lmr_130_NSBH_43K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['chi_1', 'chi_1_in_plane', 'chi_2', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'dec', 'geocent_time', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'chi_1': array([0.0144599 , 0.10657136, 0.12034966, ..., 0.03287625, 0.04336294,
#         0.05475446]),
#  'chi_1_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_eff': array([0.00910877, 0.06755963, 0.07904483, ..., 0.01927937, 0.03718532,
#         0.03908466]),
#  'chi_p': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chirp_mass': array([6.04444548, 3.72192373, 8.89124972, ..., 3.87008057, 8.56103115,
#         3.55817881]),
#  'chirp_mass_source': array([1.76388419, 1.86889193, 2.35714404, ..., 1.52681075, 2.41852772,
#         1.5849116 ]),
#  'dec': array([-0.2602162 ,  0.16939506,  1.28212516, ...,  0.33632515,
#         -1.23313719, -0.4495149 ]),
#  'geocent_time': array([1.89302402e+09, 1.89302413e+09, 1.89302705e+09, ...,
#         1.92461610e+09, 1.92461813e+09, 1.92461948e+09]),
#  'lambda_1': array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %% [markdown]
# ## BNS

# %%
samples_file = os.path.join(data_dir, 'pop2_m_FP4_spin_NS_fref_5.0_z_MD_lmr_130_BNS_109K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['chi_1', 'chi_1_in_plane', 'chi_2', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'dec', 'geocent_time', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'chi_1': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_1_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_eff': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_p': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chirp_mass': array([3.8525839 , 5.53582696, 3.19344483, ..., 1.32348974, 4.84621438,
#         3.27344047]),
#  'chirp_mass_source': array([1.21441295, 1.25863005, 1.20688359, ..., 1.13612545, 1.11133682,
#         1.17953602]),
#  'dec': array([-0.35989025, -0.19969113, -0.07872933, ..., -0.40489997,
#          0.07719794,  0.55873772]),
#  'geocent_time': array([1.89302405e+09, 1.89302439e+09, 1.89302483e+09, ...,
#         1.92462053e+09, 1.92462088e+09, 1.92462109e+09]),
#  'lambda_1': array([327.00877483, 179.18560864, 127.02287276, ..., 453.72351836,
#         590.15031523, 300.56144922]),
# ...
