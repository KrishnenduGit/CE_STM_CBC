# %%
import h5py
import pylab as plt
import os

# %%
data_dir = '/home/divyajyoti/ACADEMIC/Projects/CE_STM/CBC/data/population_samples/pop1/'

# %% [markdown]
# ## BBH

# %%
samples_file = os.path.join(data_dir, 'pop1_m_FP4_spin_IB_fref_5.0_z_MD_lmr_130_BBH_27K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['a_1', 'a_2', 'chi_1_in_plane', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'cos_tilt_1', 'cos_tilt_2', 'dec', 'geocent_time', 'iota', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'phi_1', 'phi_12', 'phi_2', 'phi_jl', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'tilt_1', 'tilt_2', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'a_1': array([0.92599958, 0.69985982, 0.53813711, ..., 0.43858671, 0.67192722,
#         0.70171158]),
#  'a_2': array([0.69043084, 0.38516659, 0.71023869, ..., 0.53859521, 0.83714709,
#         0.01769006]),
#  'chi_1_in_plane': array([0.91264748, 0.46782843, 0.23892055, ..., 0.35243009, 0.44845521,
#         0.09523198]),
#  'chi_2_in_plane': array([0.58585056, 0.38362546, 0.59425423, ..., 0.48412544, 0.74457365,
#         0.01095589]),
#  'chi_eff': array([-0.09974744, -0.28360041,  0.05828528, ..., -0.02285462,
#          0.44626864,  0.34882752]),
#  'chi_p': array([0.91264748, 0.46782843, 0.55892826, ..., 0.44019856, 0.61884164,
#         0.09523198]),
#  'chirp_mass': array([33.47227157, 31.17940804, 16.22313032, ..., 18.70920196,
#         15.7002173 , 19.11706811]),
#  'chirp_mass_source': array([8.88011266, 7.51452422, 7.216071  , ..., 8.15625292, 7.56251757,
#         7.6760758 ]),
#  'cos_tilt_1': array([ 0.16920499, -0.74374793,  0.89603814, ..., -0.59522575,
# ...

# %% [markdown]
# ## NSBH

# %%
samples_file = os.path.join(data_dir, 'pop1_m_FP4_spin_GNS_fref_5.0_z_MD_lmr_130_NSBH_30K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['chi_1', 'chi_1_in_plane', 'chi_2', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'dec', 'geocent_time', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'chi_1': array([0.15709648, 0.0057252 , 0.01267221, ..., 0.11262214, 0.14497999,
#         0.10953696]),
#  'chi_1_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_eff': array([0.13783454, 0.00472614, 0.0087793 , ..., 0.09856544, 0.13501813,
#         0.09817135]),
#  'chi_p': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chirp_mass': array([ 6.58189638, 12.78246726,  4.33590533, ..., 11.37526403,
#         21.39251048, 10.55216701]),
#  'chirp_mass_source': array([2.88037414, 3.16607621, 1.77107784, ..., 2.52335887, 5.622224  ,
#         5.43070649]),
#  'dec': array([ 0.61392497,  0.07157609,  0.29311544, ..., -0.32746268,
#         -0.44541856, -0.71877565]),
#  'geocent_time': array([1.89302622e+09, 1.89302668e+09, 1.89302750e+09, ...,
#         1.92458375e+09, 1.92458541e+09, 1.92458672e+09]),
#  'lambda_1': array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %% [markdown]
# ## BNS

# %%
samples_file = os.path.join(data_dir, 'pop1_m_FP4_spin_NS_fref_5.0_z_MD_lmr_130_BNS_129K_samples.h5')

# %%
with h5py.File(samples_file, 'r') as f:
    print(f.keys())
    samples = {key:val[()] for key, val in f.items() if key != 'config'}
# Out:
# <KeysViewHDF5 ['chi_1', 'chi_1_in_plane', 'chi_2', 'chi_2_in_plane', 'chi_eff', 'chi_p', 'chirp_mass', 'chirp_mass_source', 'config', 'dec', 'geocent_time', 'lambda_1', 'lambda_2', 'luminosity_distance', 'mass_1', 'mass_1_source', 'mass_2', 'mass_2_source', 'mass_ratio', 'phase', 'psi', 'ra', 'redshift', 'reference_frequency', 'spin_1x', 'spin_1y', 'spin_1z', 'spin_2x', 'spin_2y', 'spin_2z', 'symmetric_mass_ratio', 'theta_jn', 'total_mass', 'total_mass_source']>

# %%
samples
# Out:
# {'chi_1': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_1_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_2_in_plane': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_eff': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chi_p': array([0., 0., 0., ..., 0., 0., 0.]),
#  'chirp_mass': array([5.14667835, 2.32598944, 4.55042362, ..., 2.60814515, 5.32723908,
#         6.86059885]),
#  'chirp_mass_source': array([1.23579406, 1.14963102, 1.21175538, ..., 1.10072063, 1.70105784,
#         1.20358732]),
#  'dec': array([ 0.10274877,  0.40910633, -1.12337509, ...,  0.48965091,
#          0.50784421, -0.34327956]),
#  'geocent_time': array([1.89302435e+09, 1.89302475e+09, 1.89302479e+09, ...,
#         1.92458783e+09, 1.92458799e+09, 1.92458823e+09]),
#  'lambda_1': array([276.6964573 , 329.06145457, 338.76591759, ..., 442.54396805,
#          18.00320959,  98.14329982]),
# ...
