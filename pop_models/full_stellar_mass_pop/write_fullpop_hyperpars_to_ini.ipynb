# %%
import popsummary
import numpy as np

# %%
pdb_file = '../data/GWTC-4_pop/analyses_AllCBC/AllCBC_FullPop.h5'
res = popsummary.popresult.PopulationResult(fname=pdb_file)

logl = res.get_hyperparameter_samples(hyperparameters=["log_likelihood"])
maxl = np.argmax(logl)

def get(name):
    return res.get_hyperparameter_samples(
        hyperparameters=[name]
    )[maxl]

hyperparams = dict(
    alpha_1=get("alpha_1"), alpha_dip=get("alpha_dip"), alpha_2=get("alpha_2"),
    NSmin=get("NSmin"), NSmax=get("NSmax"),
    BHmin=get("BHmin"), BHmax=get("BHmax"),
    UPPERmin=get("UPPERmin"), UPPERmax=get("UPPERmax"),
    n0=get("n0"), n1=get("n1"),
    n2=get("n2"), n3=get("n3"),
    n4=get("n4"), n5=get("n5"),
    mix1=get("mix1"), mu1=get("mu1"), sig1=get("sig1"),
    mix2=get("mix2"), mu2=get("mu2"), sig2=get("sig2"),
    A=get("A"), A2=get("A2"),
    beta_pair_1=get("beta_pair_1"), beta_pair_2=get("beta_pair_2"),
    mbreak=get("mbreak")
)
# Out:
# opening existing popsummary file: ../data/GWTC-4_pop/analyses_AllCBC/AllCBC_FullPop.h5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 25
#       7 def get(name):
#       8     return res.get_hyperparameter_samples(
#       9         hyperparameters=[name]
#      10     )[maxl]
#      12 hyperparams = dict(
#      13     alpha_1=get("alpha_1"), alpha_dip=get("alpha_dip"), alpha_2=get("alpha_2"),
#      14     NSmin=get("NSmin"), NSmax=get("NSmax"),
#      15     BHmin=get("BHmin"), BHmax=get("BHmax"),
#      16     UPPERmin=get("UPPERmin"), UPPERmax=get("UPPERmax"),
#      17     n0=get("n0"), n1=get("n1"),
#      18     n2=get("n2"), n3=get("n3"),
#      19     n4=get("n4"), n5=get("n5"),
#      20     mix1=get("mix1"), mu1=get("mu1"), sig1=get("sig1"),
#      21     mix2=get("mix2"), mu2=get("mu2"), sig2=get("sig2"),
#      22     A=get("A"), A2=get("A2"),
#      23     beta_pair_1=get("beta_pair_1"), beta_pair_2=get("beta_pair_2"),
#      24     mbreak=get("mbreak"),
# ---> 25     mmin=get("mmin"), mmax=get("mmax")
#      26 )
#
# Cell In[9], line 8, in get(name)
#       7 def get(name):
# ----> 8     return res.get_hyperparameter_samples(
#       9         hyperparameters=[name]
#      10     )[maxl]
#
# File ~/miniconda3/envs/spe_ngloc_mygwf_mypycbc/lib/python3.11/site-packages/popsummary/popresult.py:202, in PopulationResult.get_hyperparameter_samples(self, hyper_sample_idx, hyperparameters, group)
#     199 with h5py.File(self.fname, 'r') as f:
#     201     mask_hyper_sample = self._mask_with_idx(hyper_sample_idx)
# --> 202     mask_hyperparameter = self._mask_with_metadata(f, 'hyperparameters', hyperparameters)
#     204     return np.array(f[group]['hyperparameter_samples']
#     205     )[mask_hyper_sample,:][:,mask_hyperparameter]
#
# File ~/miniconda3/envs/spe_ngloc_mygwf_mypycbc/lib/python3.11/site-packages/popsummary/popresult.py:822, in PopulationResult._mask_with_metadata(self, f, field, selections)
#     820 else:
#     821     if isinstance(selections, (list, np.ndarray)):
# --> 822         mask = [np.flatnonzero(f.attrs[field] == selection)[0] for selection in selections]
#     823     else:
#     824         mask = np.flatnonzero(f.attrs[field] == selections)
#
# File ~/miniconda3/envs/spe_ngloc_mygwf_mypycbc/lib/python3.11/site-packages/popsummary/popresult.py:822, in <listcomp>(.0)
#     820 else:
#     821     if isinstance(selections, (list, np.ndarray)):
# --> 822         mask = [np.flatnonzero(f.attrs[field] == selection)[0] for selection in selections]
#     823     else:
#     824         mask = np.flatnonzero(f.attrs[field] == selections)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
hyperparams
# Out:
# {'alpha_1': array([-4.50928264]),
#  'alpha_dip': array([-1.6797692]),
#  'alpha_2': array([-0.90203468]),
#  'NSmin': array([1.17636651]),
#  'NSmax': array([4.09474414]),
#  'BHmin': array([7.76395494]),
#  'BHmax': array([152.05597923]),
#  'UPPERmin': array([38.27741543]),
#  'UPPERmax': array([66.57670527]),
#  'n0': array([50.]),
#  'n1': array([50.]),
#  'n2': array([50.]),
#  'n3': array([30.]),
#  'n4': array([30.]),
#  'n5': array([10.0410722]),
#  'mix1': array([735.47327554]),
#  'mu1': array([37.8111964]),
#  'sig1': array([17.12643064]),
#  'mix2': array([211.73332683]),
#  'mu2': array([8.89774204]),
#  'sig2': array([1.04469263]),
#  'A': array([0.09146242]),
#  'A2': array([0.82816522]),
#  'beta_pair_1': array([0.96413796]),
#  'beta_pair_2': array([2.16003565]),
#  'mbreak': array([5.])}

# %%
with open('pdb_hyperpar_defaults_test.ini', 'w') as f:
    f.write("[hyperparameters]\n")
    for key, value in hyperparams.items():
        f.write(f"{key} = {value[0]}\n")
